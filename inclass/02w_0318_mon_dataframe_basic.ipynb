# %% [markdown]
# <a href="https://colab.research.google.com/github/ghddusghk46/2024-1-my-BDA/blob/main/inclass/02w_0318_mon_dataframe_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 파이썬 설치 확인

# %%
#63
import sys
import pandas as pd
import numpy as np

print(sys.version)
print(np.__version__)
print(pd.__version__)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# 1.25.2
# 1.5.3

# %% [markdown]
# # 코랩에서 한글 처리

# %%
# !pip install koreanize_matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 29.7 MB/s eta 0:00:00
# ...

# %%
#해상도 선명하게
# %config InlineBackend.figure_format = 'retina'

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.countplot(titanic, x="sex");

# %%
sns.countplot(titanic, x='class');

# %%
sns.countplot(data = titanic, x='class', hue = 'alive'); # x축 class, alive색 별 표현

# %%
titanic.pclass.unique()
# Out:
# array([3, 1, 2])

# %%
titanic.pclass.values
# Out:
# array([3, 1, 3, 1, 3, 3, 1, 3, 3, 2, 3, 1, 3, 3, 3, 2, 3, 2, 3, 3, 2, 2,
#        3, 1, 3, 3, 3, 1, 3, 3, 1, 1, 3, 2, 1, 1, 3, 3, 3, 3, 3, 2, 3, 2,
#        3, 3, 3, 3, 3, 3, 3, 3, 1, 2, 1, 1, 2, 3, 2, 3, 3, 1, 1, 3, 1, 3,
#        2, 3, 3, 3, 2, 3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 2, 3, 3, 3,
#        1, 3, 3, 3, 1, 3, 3, 3, 1, 1, 2, 2, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3,
#        1, 3, 3, 3, 3, 3, 3, 2, 1, 3, 2, 3, 2, 2, 1, 3, 3, 3, 3, 3, 3, 3,
#        3, 2, 2, 2, 1, 1, 3, 1, 3, 3, 3, 3, 2, 2, 3, 3, 2, 2, 2, 1, 3, 3,
#        3, 1, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 3, 1, 3, 1, 3, 3, 3, 1, 3,
#        3, 1, 2, 3, 3, 2, 3, 2, 3, 1, 3, 1, 3, 3, 2, 2, 3, 2, 1, 1, 3, 3,
#        3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 1, 3, 2, 3, 2, 3, 1, 3, 2, 1, 2,
#        3, 2, 3, 3, 1, 3, 2, 3, 2, 3, 1, 3, 2, 3, 2, 3, 2, 2, 2, 2, 3, 3,
#        2, 3, 3, 1, 3, 2, 1, 2, 3, 3, 1, 3, 3, 3, 1, 1, 1, 2, 3, 3, 1, 1,
#        3, 2, 3, 3, 1, 1, 1, 3, 2, 1, 3, 1, 3, 2, 3, 3, 3, 3, 3, 3, 1, 3,
# ...

# %%
titanic["pclass"].unique() #9와 동일
# Out:
# array([3, 1, 2])

# %%
titanic.pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
titanic.nunique() #데이터프레임의 모든 열에 있는 값의 개수
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
titanic[['pclass', 'who']].values
# Out:
# array([[3, 'man'],
#        [1, 'woman'],
#        [3, 'woman'],
#        ...,
#        [3, 'woman'],
#        [1, 'man'],
#        [3, 'man']], dtype=object)

# %%
titanic.groupby('sex').count() # 타이타닉을 성별로 나눠서 몇 사람씩 있는지 알기
# Out:
#         survived  pclass  age  sibsp  parch  fare  embarked  class  who  \
# sex
# female       314     314  261    314    314   314       312    314  314
# male         577     577  453    577    577   577       577    577  577
#
#         adult_male  deck  embark_town  alive  alone
# sex
# female         314    97          312    314    314
# male           577   106          577    577    577

# %%
titanic.groupby('class').count()
# Out:
#         survived  pclass  sex  age  sibsp  parch  fare  embarked  who  \
# class
# First        216     216  216  186    216    216   216       214  216
# Second       184     184  184  173    184    184   184       184  184
# Third        491     491  491  355    491    491   491       491  491
#
#         adult_male  deck  embark_town  alive  alone
# class
# First          216   175          214    216    216
# Second         184    16          184    184    184
# Third          491    12          491    491    491

# %%
sns.barplot(x="sex", y="survived", data=titanic);

# %%
sns.barplot(x="pclass", y="survived", data=titanic);

# %%
sns.barplot(x="pclass", y="survived", hue="sex", data=titanic);

# %% [markdown]
# ## 단원 4 데이터프레임의 세계로!

# %%
import pandas as pd
df = pd.DataFrame({"name"     : ["김지훈", "이유진", "박동현", "김진지"],
                   "english"  : [90, 80, 60, 70],
                   "math"     : [50, 60, 10, 20]})
df
# Out:
#   name  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60    10
# 3  김진지       70    20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     4 non-null      object
#  1   english  4 non-null      int64
#  2   math     4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
df.describe()
# Out:
#          english       math
# count   4.000000   4.000000
# mean   75.000000  35.000000
# std    12.909944  23.804761
# min    60.000000  10.000000
# 25%    67.500000  17.500000
# 50%    75.000000  35.000000
# 75%    82.500000  52.500000
# max    90.000000  60.000000

# %%
df.describe(include = "all")
# Out:
#        name    english       math
# count     4   4.000000   4.000000
# unique    4        NaN        NaN
# top     김지훈        NaN        NaN
# freq      1        NaN        NaN
# mean    NaN  75.000000  35.000000
# std     NaN  12.909944  23.804761
# min     NaN  60.000000  10.000000
# 25%     NaN  67.500000  17.500000
# 50%     NaN  75.000000  35.000000
# 75%     NaN  82.500000  52.500000
# max     NaN  90.000000  60.000000

# %% [markdown]
# ##  특정 변수의 값 추출하기

# %%
df["math"]
# Out:
# 0    50
# 1    60
# 2    10
# 3    20
# Name: math, dtype: int64

# %%
type(df["math"])
# Out:
# pandas.core.series.Series

# %%
sum(df["english"])
# Out:
# 300

# %%
sum(df["math"])
# Out:
# 140

# %%
sum(df["english"])/4
# Out:
# 75.0

# %%
sum(df["english"])/len(df)
# Out:
# 75.0

# %%
df.sum(numeric_only=True)
# Out:
# english    300
# math       140
# dtype: int64

# %%
df.sum(axis=0, numeric_only = True)
# Out:
# english    300
# math       140
# dtype: int64

# %%
df.sum(axis=1, numeric_only = True)
# Out:
# 0    140
# 1    140
# 2     70
# 3     90
# dtype: int64

# %%
df.sum(axis = "columns", numeric_only = True)
# Out:
# 0    140
# 1    140
# 2     70
# 3     90
# dtype: int64

# %%
df.sum(axis = "index", numeric_only = True)
# Out:
# english    300
# math       140
# dtype: int64

# %%
df.mean(axis = "index", numeric_only = "True")
# Out:
# english    75.0
# math       35.0
# dtype: float64

# %%
df.mean(axis = "columns", numeric_only = True)
# Out:
# 0    70.0
# 1    70.0
# 2    35.0
# 3    45.0
# dtype: float64

# %% [markdown]
# ## 혼자서 해보기

# %%
import pandas as pd
df = pd.DataFrame({"제품"     : ["사과", "딸기", "수박"],
                   "가격"  : [1800, 1500, 3000],
                   "판매량"     : [24, 38, 13]})
df
# Out:
#    제품    가격  판매량
# 0  사과  1800   24
# 1  딸기  1500   38
# 2  수박  3000   13

# %%
df.sum(axis=0, numeric_only = True)/3
# Out:
# 가격     2100.0
# 판매량      25.0
# dtype: float64

# %%
df.sum(numeric_only = True)
# Out:
# 가격     6300
# 판매량      75
# dtype: int64

# %%
df.mean(numeric_only = True)
# Out:
# 가격     2100.0
# 판매량      25.0
# dtype: float64

# %%
df.sum(axis = 1, numeric_only = True)
# Out:
# 0    1824
# 1    1538
# 2    3013
# dtype: int64

# %% [markdown]
# ## 4-3 외부 데이터 이용하기 - 축적된 시험 성적 데이터를 불러오자!

# %%
df_exam = pd.read_excel('excel_exam.xlsx') # 엑셀 파일을 불러와 df_exam에 할당
df_exam # 출력
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
sum(df_exam['english'])/20
# Out:
# 84.9

# %%
sum(df_exam['english'])/len(df_exam)
# Out:
# 84.9

# %%
df_exam['english'].mean()
# Out:
# 84.9

# %%
# 과학 성적 평균
print(sum(df_exam['science']) / 20)
print(sum(df_exam['science']) / len(df_exam))
print(df_exam['science'].mean())
# Out:
# 59.45
# 59.45
# 59.45

# %% [markdown]
# ### 엑셀 파일의 첫 번째 행이 변수명이 아니라면?

# %%
df_exam_novar = pd.read_excel('excel_exam_novar.xlsx')
df_exam_novar
# Out:
#    1  1.1  50  98  50.1
# 0  2    1  60  97    60
# 1  3    2  25  80    65
# 2  4    2  50  89    98
# 3  5    3  20  98    15
# 4  6    3  50  98    45
# 5  7    4  46  98    65
# 6  8    4  48  87    12

# %%
df_exam_novar = pd.read_excel('excel_exam_novar.xlsx', header = None)
df_exam_novar
# Out:
#    0  1   2   3   4
# 0  1  1  50  98  50
# 1  2  1  60  97  60
# 2  3  2  25  80  65
# 3  4  2  50  89  98
# 4  5  3  20  98  15
# 5  6  3  50  98  45
# 6  7  4  46  98  65
# 7  8  4  48  87  12

# %% [markdown]
# #### 엑셀 파일에 시트가 여러 개 있다면?

# %%
# sheet2 시트의 데이터 불러오기
df_exam = pd.read_excel('excel_exam.xlsx', sheet_name = 'Sheet2')
df_exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1   100      100       98
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
df_exam.tail()
# Out:
#     id  nclass  math  english  science
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# # csv 파일 불러오기

# %%
df_csv_exam = pd.read_csv('exam.csv')
df_csv_exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
df_csv_exam.to_csv("output_newdata.csv")

# %%
df_csv_exam.to_csv('output_newdata_noindex.csv', index = False)

# %% [markdown]
# # 정리하기

# %%
# 1. 데이터 프레임 만들기
df = pd.DataFrame({"name"     : ["김지훈", "이유진", "박동현", "김민지"],
                   "english"  : [90, 80, 60, 70],
                   "math"     : [50, 60, 10, 20]})

# 2.외부 데이터 불러오기

 # 엑셀 파일 불러오기
df_exam = pd.read_excel('excel_exam.xlsx')

 # CSV 파일 불러오기
df_csv_exam = pd.read_csv('exam.csv')

 # CSV 파일로 저장하기
df_midterm = pd.DataFrame({'english' : [90, 80, 60, 70],
                           'math'    : [50, 60, 100, 20],
                           'nclass'  : [1, 1, 2, 3]})
df_midterm.to_csv('output_newdata2.csv')
df_midterm.to_csv('output_newdata3.csv', index = False)
